# %% [markdown]
# * Import

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.style.use('ggplot')
import calendar

# %%
uber_data = pd.read_csv ('./Data/My Uber Drives - 2016.csv')
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_data.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
uber_data.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
sns.heatmap(uber_data.isnull(), yticklabels=False, cmap = "viridis")

# %%
uber_data = uber_data.dropna()
sns.heatmap(uber_data.isnull(),yticklabels=False, cmap="viridis")

# %% [markdown]
# * Transforming the Data
#
# Getting an hour, day, days of the week, a month from the date of the trip.

# %%
uber_data['START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'], format="%m/%d/%Y %H:%M" )
uber_data['END_DATE*'] = pd.to_datetime(uber_data['END_DATE*'], format="%m/%d/%Y %H:%M")
# Out:
# <ipython-input-8-641bb90a6e2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['START_DATE*'] = pd.to_datetime(uber_data['START_DATE*'], format="%m/%d/%Y %H:%M" )
# <ipython-input-8-641bb90a6e2f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['END_DATE*'] = pd.to_datetime(uber_data['END_DATE*'], format="%m/%d/%Y %H:%M")

# %%
hour = []
day = []
dayofweek = []
month = []
weekday = []
for x in uber_data['START_DATE*']:
    hour.append(x.hour)
    day.append(x.day)
    dayofweek.append(x.dayofweek)
    month.append(x.month)
    weekday.append(calendar.day_name[dayofweek[-1]])
uber_data['HOUR'] = hour
uber_data['DAY'] = day
uber_data['DAY_OF_WEEK'] = dayofweek
uber_data['MONTH'] = month
uber_data['WEEKDAY'] = weekday
# Out:
# <ipython-input-9-3a915210953e>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['HOUR'] = hour
# <ipython-input-9-3a915210953e>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['DAY'] = day
# <ipython-input-9-3a915210953e>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['DAY_OF_WEEK'] = dayofweek
# <ipython-input-9-3a915210953e>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['MONTH'] = month
# <ipython-input-9-3a915210953e>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['WEEKDAY'] = weekday

# %%
uber_data.head()
# Out:
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY
# 0     Friday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday
# 5  Wednesday

# %% [markdown]
# * Finding travelling time

# %%
time = []
uber_data['TRAVELLING_TIME'] = uber_data['END_DATE*'] - uber_data['START_DATE*']
for i in uber_data['TRAVELLING_TIME']:
    time.append(i.seconds/60)
uber_data['TRAVELLING_TIME'] = time
uber_data.head()
# Out:
# <ipython-input-16-96fadc71929e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['TRAVELLING_TIME'] = uber_data['END_DATE*'] - uber_data['START_DATE*']
# <ipython-input-16-96fadc71929e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['TRAVELLING_TIME'] = time
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY  TRAVELLING_TIME
# 0     Friday              6.0
# 2   Saturday             13.0
# 3    Tuesday             14.0
# 4  Wednesday             67.0
# 5  Wednesday              4.0

# %% [markdown]
# * Calculating Avg speed of the Trip

# %%
uber_data['TRAVELLING_TIME'] = uber_data['TRAVELLING_TIME']/60
uber_data['SPEED'] = uber_data['MILES*']/uber_data['TRAVELLING_TIME']
uber_data.head()
# Out:
# <ipython-input-17-efd16ae13a20>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['TRAVELLING_TIME'] = uber_data['TRAVELLING_TIME']/60
# <ipython-input-17-efd16ae13a20>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uber_data['SPEED'] = uber_data['MILES*']/uber_data['TRAVELLING_TIME']
#           START_DATE*           END_DATE* CATEGORY*           START*  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business      Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business      Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business      Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business      Fort Pierce
# 5 2016-01-06 17:15:00 2016-01-06 17:19:00  Business  West Palm Beach
#
#              STOP*  MILES*         PURPOSE*  HOUR  DAY  DAY_OF_WEEK  MONTH  \
# 0      Fort Pierce     5.1   Meal/Entertain    21    1            4      1
# 2      Fort Pierce     4.8  Errand/Supplies    20    2            5      1
# 3      Fort Pierce     4.7          Meeting    17    5            1      1
# 4  West Palm Beach    63.7   Customer Visit    14    6            2      1
# 5  West Palm Beach     4.3   Meal/Entertain    17    6            2      1
#
#      WEEKDAY  TRAVELLING_TIME      SPEED
# 0     Friday         0.100000  51.000000
# 2   Saturday         0.216667  22.153846
# 3    Tuesday         0.233333  20.142857
# 4  Wednesday         1.116667  57.044776
# 5  Wednesday         0.066667  64.500000

# %% [markdown]
# * Visualizing the Data
#
# Different categories of data. From data, we can see most of the people use UBER for business purposes.

# %%
sns.countplot(uber_data['CATEGORY*'])

# %% [markdown]
# * Histogram for miles. Most of people not having a long trip.

# %%
uber_data['MILES*'].plot.hist()

# %% [markdown]
# ##### Trips for purpose. Mostly the purpose of the trip is meeting and meal/entertain.

# %%
plt.figure(figsize = (20,5))
ax=sns.countplot(uber_data['PURPOSE*'])
ax.set_title("Trips for Purpose", fontsize = 20)
plt.xlabel("PURPOSE",fontsize=17)
plt.ylabel("count", fontsize=17)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), color='black', size=15, ha="center")

# %% [markdown]
# * Trips per hour of the day.

# %%
plt.figure(figsize = (20,5))
ax=sns.countplot(uber_data['HOUR'])
ax.set_title("Trips per hour of the day", fontsize = 20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), color='black', size=15, ha="center")

# %% [markdown]
# * Trips per day of a week.

# %%
plt.figure(figsize = (20,5))
ax=sns.countplot(uber_data['WEEKDAY'])
ax.set_title("Trips per day of a week", fontsize = 20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), color='black', size=15, ha="center")

# %% [markdown]
# * Trips per day of the month

# %%
plt.figure(figsize = (20,5))
ax=sns.countplot(uber_data['DAY'])
ax.set_title("Trips per day of the Month", fontsize = 20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), color='black', size=15, ha="center")

# %% [markdown]
# * Trips in a month.

# %%
plt.figure(figsize = (20,5))
ax=sns.countplot(uber_data['MONTH'])
ax.set_title("Trips per day of the Month", fontsize = 20)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()), color='black', size=15, ha="center")

# %% [markdown]
# * The starting points of trips.

# %%
uber_data['START*'].value_counts().plot(kind = 'bar', figsize = (25,5), color = 'blue')

# %% [markdown]
# * Comparing all the purpose with miles, hour, day of the month, day of the week, month, Travelling time.

# %%
uber_data.groupby('PURPOSE*').mean().plot(kind='bar', figsize=(15,5))
